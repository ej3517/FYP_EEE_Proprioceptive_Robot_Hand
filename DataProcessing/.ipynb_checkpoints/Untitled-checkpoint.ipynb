# %%
import json

with open('../Control/data_pos_trial.json') as f:
    full_data_dict = json.load(f)

poses_drf = [60,65,70]
finger_gaps = [34,42,50]
sqrt_sides = [20,25,30]
imgs = [1,2]
data_list=[[],[]]

for img in imgs:
    for pose in poses_drf:
        for gap in finger_gaps:
            for dim in sqrt_sides:
                dict_key = "dim_"+str(dim)+"_pose_"+str(pose)+"_gap_"+str(gap)+"_"+str(img)
                print(full_data_dict[dict_key])
# Out:
# {'LF_motion1': [[2329, 2328, 2323, 2316, 2309, 2299, 2291, 2283, 2276, 2268, 2259, 2251, 2243, 2235, 2227, 2219, 2211, 2203, 2195, 2186, 2178, 2170, 2162, 2154, 2146, 2138, 2130, 2121, 2113, 2106, 2099, 2092, 2084, 2076, 2069, 2061, 2053, 2045, 2037, 2029, 2021, 2013, 2005, 1997, 1988, 1980, 1972, 1965, 1957, 1949, 1940, 1932, 1924, 1916, 1908, 1900, 1892, 1884, 1876, 1868, 1860, 1852, 1844, 1836, 1828, 1820, 1812, 1804, 1796, 1788, 1780], [6.044645071029663, 6.09264612197876, 6.140779972076416, 6.1886560916900635, 6.236785173416138, 6.28463888168335, 6.332605838775635, 6.380626916885376, 6.428593873977661, 6.476608991622925, 6.5246148109436035, 6.572950124740601, 6.620550870895386, 6.668578147888184, 6.717057943344116, 6.764586925506592, 6.812600135803223, 6.860589027404785, 6.908630132675171, 6.956571817398071, 7.004590034484863, 7.052560091018677, 7.1006011962890625, 7.1486289501190186, 7.196620941162109, 7.2445759773254395, 7.292625904083252, 7.340538024902344, 7.388638973236084,
# ...
